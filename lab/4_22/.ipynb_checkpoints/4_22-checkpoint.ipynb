# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fi = [0.996,0.999,0.987,0.96,0.919,0.866,0.8,0.727,0.646,0.561,0.474,0.388,0.305,0.228,0.159,0.101,0.054,0.022,0.004]
nfi = np.array(fi)

# %%
I = [0.98,0.98,0.97,0.96,0.94,0.89,0.87,0.76,0.67,0.56,0.48,0.39,0.34,0.23,0.17,0.11,0.05,0.02,0]
nI = np.array(I)

# %%
plt.scatter(nfi,nI)

# %%
fi2 = [0.996,0.978,0.946,0.899,0.841,0.72,0.695,0.612,0.526,0.439,0.354,0.273,0.199,0.134,0.081,0.04,0.013,0.009,0.004]
nfi2 =np.array(fi2)

# %%
I2 =[0.96,0.9,0.9,0.85,0.83,0.8,0.73,0.62,0.55,0.46,0.34,0.26,0.19,0.12,0.07,0.03,0.009,0,0]
nI2 = np.array(I2)

# %%
plt.scatter(nfi2,nI2)
