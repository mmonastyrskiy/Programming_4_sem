# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
I = [6,4,2,0,-2,-4,-6]
fi = [115.7,69.17,38.64,0,-39.88,-86.62,-112.58]

# %%
nI = np.array(I)

# %%
nfi = np.array(fi)

# %%
plt.scatter(nI,nfi)
