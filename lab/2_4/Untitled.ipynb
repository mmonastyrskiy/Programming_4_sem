# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
p = [0.49,0.45,0.39,0.35,0.29,0.25]
n = [1.32,1.25,1.1,0.95,0.79,0.63]

np_ = np.array(p)

# %%
nn = np.array(n)

# %%
a = plt.plot(np_,nn)
plt.savefig("1.jpg")
