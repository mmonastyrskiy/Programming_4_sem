# %%
import numpy as np
from matplotlib import pyplot as plt
import math as m

# %%
Uvh = 1
Uvih=K= [1,0.95,0.9,0.85,0.8,0.75,0.707,0.6,0.5,0.4,0.3,0.2,0.1]

# %%
w = [20,640,800,1100,1350,1600,1800,2400,3000,4000,5600,9000,18000]
lw = [m.log10(x) for x in w]
lw
# Out:
# [1.3010299956639813,
#  2.806179973983887,
#  2.9030899869919438,
#  3.041392685158225,
#  3.130333768495006,
#  3.2041199826559246,
#  3.255272505103306,
#  3.380211241711606,
#  3.4771212547196626,
#  3.6020599913279625,
#  3.7481880270062002,
#  3.9542425094393248,
#  4.2552725051033065]

# %%
w_n = np.array(lw)
K_n = np.array(K)

# %%
plt.plot(w_n,K_n,marker='o')

# %%
w2=[1e5,5000,3400,2700,2300,1900,1700,1300,1000,750,520,34,17]
lw2 = [m.log10(x) for x in w2]
lw2
# Out:
# [5.0,
#  3.6989700043360187,
#  3.531478917042255,
#  3.4313637641589874,
#  3.361727836017593,
#  3.278753600952829,
#  3.230448921378274,
#  3.113943352306837,
#  3.0,
#  2.8750612633917,
#  2.716003343634799,
#  1.5314789170422551,
#  1.2304489213782739]

# %%
w2_n = np.array(lw2)

# %%
plt.plot(w2_n,K_n,marker='o')
